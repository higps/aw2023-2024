# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

# %%
df_original = pd.read_csv('kc_house_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\MariusDyrseth\Downloads\preprocessing_text2num.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df_original = pd.read_csv('kc_house_data.csv')
#
# File c:\Users\MariusDyrseth\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\MariusDyrseth\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\MariusDyrseth\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\MariusDyrseth\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\MariusDyrseth\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kc_house_data.csv'

# %%
df_original.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
features_names = [
    'bedrooms', 'bathrooms', 'sqft_living',
    'sqft_lot', 'floors', 'waterfront']

#df_original['sqft_lot'].hist(bins=50)
df_original[features_names].hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'sqft_living'}>,
#         <Axes: title={'center': 'sqft_lot'}>],
#        [<Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'waterfront'}>]], dtype=object)

# %%
df_original['sqft_living_log'] = np.log(df_original['sqft_living'])
df_original['sqft_lot_log'] = np.log(df_original['sqft_lot'])

features_names = [
    'bedrooms', 'bathrooms', 'sqft_living_log',
    'sqft_lot_log', 'floors', 'waterfront']

df_original[features_names].hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'sqft_living_log'}>,
#         <Axes: title={'center': 'sqft_lot_log'}>],
#        [<Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'waterfront'}>]], dtype=object)

# %%
# Faking missing values
idx = np.random.randint(0,21000, 2000)
df_original.loc[idx,'bedrooms'] = np.nan

# %%
bedroom_imputer = SimpleImputer(strategy='median')
bedroom_imputer.fit(df_original[['bedrooms']])
df_original[['bedrooms_no_nan']] = bedroom_imputer.transform(df_original[['bedrooms']])

# %%
features_names = [
    'bedrooms_no_nan', 'bathrooms', 'sqft_living_log',
    'sqft_lot_log', 'floors', 'waterfront']

features_min_max_sc = ['bathrooms', 'floors'] 

b_f_minmax_sc = MinMaxScaler()
b_f_minmax_sc.fit(df_original[features_min_max_sc])
df_original[['bathrooms_mm', 'floors_mm']] = b_f_minmax_sc.transform(df_original[features_min_max_sc])

# %%
features_std_sc = ['bedrooms_no_nan', 'sqft_living_log', 'sqft_lot_log']
b_sl_sl_std_sc = StandardScaler()
b_sl_sl_std_sc.fit(df_original[features_std_sc])
df_original[['bedrooms_no_nan_std_sc', 'sqft_living_log_std_sc', 'sqft_lot_log_std_sc']] = b_sl_sl_std_sc.transform(df_original[features_std_sc])

# %%
features_names = [
    'bedrooms_no_nan_std_sc', 'bathrooms_mm', 'sqft_living_log_std_sc',
    'sqft_lot_log_std_sc', 'floors_mm', 'waterfront']
df_original[features_names].hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'bedrooms_no_nan_std_sc'}>,
#         <Axes: title={'center': 'bathrooms_mm'}>],
#        [<Axes: title={'center': 'sqft_living_log_std_sc'}>,
#         <Axes: title={'center': 'sqft_lot_log_std_sc'}>],
#        [<Axes: title={'center': 'floors_mm'}>,
#         <Axes: title={'center': 'waterfront'}>]], dtype=object)

# %%
# low_grade_rows = df_original['grade']<7
# df_original.loc[low_grade_rows,'grade_text'] = 'low'

# mid_grade_rows = (df_original['grade']>=7) & ((df_original['grade']<=8))
# df_original.loc[mid_grade_rows,'grade_text'] = 'mid'

# high_grade_rows = df_original['grade']>8
# df_original.loc[high_grade_rows,'grade_text'] = 'high'

def grade_num_to_text(grade):
    if grade<7:
        return 'low'
    elif grade>8:
        return 'high'
    else:
        return 'mid'

df_original['grade_text'] = df_original['grade'].map(grade_num_to_text)

# def grade_num_to_text(row):
#     if row<7:
#         return 'low'
#     elif row>8:
#         return 'high'
#     else:
#         return 'mid'

# a = df_original['grade'].apply(grade_num_to_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\MariusDyrseth\Downloads\preprocessing_text2num.ipynb Cell 11 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a>     else:
#      <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X13sZmlsZQ%3D%3D?line=15'>16</a>         return 'mid'
# ---> <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X13sZmlsZQ%3D%3D?line=17'>18</a> df_original['grade_text'] = df_original['grade'].map(grade_num_to_text)
#      <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X13sZmlsZQ%3D%3D?line=19'>20</a> # def grade_num_to_text(row):
#      <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X13sZmlsZQ%3D%3D?line=20'>21</a> #     if row<7:
#      <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X13sZmlsZQ%3D%3D?line=21'>22</a> #         return 'low'
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X13sZmlsZQ%3D%3D?line=26'>27</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X13sZmlsZQ%3D%3D?line=27'>28</a> # a = df_original['grade'].apply(grade_num_to_text)
#
# NameError: name 'df_original' is not defined

# %%
oe_columns = ['grade_text']
oe_grades = OrdinalEncoder()
oe_grades.fit(df_original[oe_columns])
df_original[['grade_text_oe']] = oe_grades.transform(df_original[oe_columns])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\MariusDyrseth\Downloads\preprocessing_text2num.ipynb Cell 12 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> oe_columns = ['grade_text']
#       <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> oe_grades = OrdinalEncoder()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> oe_grades.fit(df_original[oe_columns])
#       <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> df_original[['grade_text_oe']] = oe_grades.transform(df_original[oe_columns])
#
# NameError: name 'df_original' is not defined

# %%
ohe_grades = OneHotEncoder(sparse_output=False)
ohe_grades.fit(df_original[oe_columns])
ohe_column_name = ['grade_high', 'grade_low', 'grade_mid']
# ohe_column_name = ohe_grades.get_feature_names_out()
df_original[ohe_column_name] = ohe_grades.transform(df_original[oe_columns])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\MariusDyrseth\Downloads\preprocessing_text2num.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> ohe_grades = OneHotEncoder(sparse_output=False)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> ohe_grades.fit(df_original[oe_columns])
#       <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> ohe_column_name = ['grade_high', 'grade_low', 'grade_mid']
#       <a href='vscode-notebook-cell:/c%3A/Users/MariusDyrseth/Downloads/preprocessing_text2num.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> # ohe_column_name = ohe_grades.get_feature_names_out()
#
# NameError: name 'df_original' is not defined

# %%
df_original['grade_text']
# Out:
# 0        mid
# 1        mid
# 2        low
# 3        mid
# 4        mid
#         ...
# 21608    mid
# 21609    mid
# 21610    mid
# 21611    mid
# 21612    mid
# Name: grade_text, Length: 21613, dtype: object

# %%
features_names = [
    'bedrooms_no_nan_std_sc', 'bathrooms_mm', 'sqft_living_log_std_sc',
    'sqft_lot_log_std_sc', 'floors_mm', 'waterfront', 'grade_high', 'grade_low', 'grade_mid']

X = np.c_[df_original[features_names]]
y = np.c_[df_original['price']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model_lr.predict(X_train)
y_test_pred = model_lr.predict(X_test)

# %%
mae_train = mean_absolute_error(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
r2_train = r2_score(y_train, y_train_pred)

print(f'MAE train: {mae_train}')
print(f'MSE train: {mse_train}')
print(f'R2 train: {r2_train}')

mae_test = mean_absolute_error(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
r2_test = r2_score(y_test, y_test_pred)

print(f'MAE test: {mae_test}')
print(f'MSE test: {mse_test}')
print(f'R2 test: {r2_test}')
df_train = 10
# Out:
# MAE train: 181463.93331544052
# MSE train: 75724763598.7651
# R2 train: 0.44076292625721014
# MAE test: 182176.87440096794
# MSE test: 76721860260.1933
# R2 test: 0.4198509698626399
